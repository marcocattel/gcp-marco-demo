# %%
# %pip list
# Out:
# Package                                Version
# -------------------------------------- --------------
# absl-py                                1.4.0
# aiohttp                                3.8.4
# aiohttp-cors                           0.7.0
# aiorwlock                              1.3.0
# aiosignal                              1.3.1
# ansiwrap                               0.8.4
# anyio                                  3.6.2
# argon2-cffi                            21.3.0
# argon2-cffi-bindings                   21.2.0
# async-timeout                          4.0.2
# asynctest                              0.13.0
# attrs                                  22.2.0
# Babel                                  2.12.1
# backcall                               0.2.0
# backoff                                2.2.1
# backports.functools-lru-cache          1.6.4
# beatrix-jupyterlab                     2023.43.153257
# beautifulsoup4                         4.12.0
# ...

# %%
import pandas as pd

# %%
pip install xgboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 3.9 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost

# %%
# %%bigquery
# SELECT *  FROM `bigquery-public-data.san_francisco_trees.street_trees` LIMIT 20
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     tree_id    legal_status                                       species  \
# 0     36561  Permitted Site                                    Tree(s) ::
# 1     44943  Permitted Site                                    Tree(s) ::
# 2     30483  Permitted Site                                    Tree(s) ::
# 3     46142  Permitted Site         Lophostemon confertus :: Brisbane Box
# 4     44538  Permitted Site                                    Tree(s) ::
# 5     44962  Permitted Site                                    Tree(s) ::
# 6     48065  Permitted Site                                    Tree(s) ::
# 7     44553  Permitted Site                                    Tree(s) ::
# 8     45022  Permitted Site                                    Tree(s) ::
# 9     48259  Permitted Site                                    Tree(s) ::
# 10    48208  Permitted Site                                    Tree(s) ::
# ...

# %%
# %%bigquery df_tree
# SELECT species, count(*) as num_trees, min(plant_date) as min_plant_date, max(plant_date) as max_plant_date
# FROM `bigquery-public-data.san_francisco_trees.street_trees` group by species LIMIT 1000
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_tree.head()
# Out:
#                                         species  num_trees  \
# 0                                    Tree(s) ::      11813
# 1         Lophostemon confertus :: Brisbane Box       8946
# 2  Melaleuca linariifolia :: Flaxleaf Paperbark        371
# 3                   Robinia x ambigua :: Locust        118
# 4    Arbutus 'Marina' :: Hybrid Strawberry Tree       5776
#
#              min_plant_date            max_plant_date
# 0 1955-09-19 00:00:00+00:00 2023-04-03 00:00:00+00:00
# 1 1969-07-28 00:00:00+00:00 2023-03-17 00:00:00+00:00
# 2 1973-08-15 00:00:00+00:00 2021-07-20 00:00:00+00:00
# 3 1997-03-15 00:00:00+00:00 2003-08-27 00:00:00+00:00
# 4 1956-02-06 00:00:00+00:00 2022-10-31 00:00:00+00:00
